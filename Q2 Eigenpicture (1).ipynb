# %%
def basic_eigenpicture(A):
    
    return

# %%
def R(theta):
    return Matrix([[cos(theta), -sin(theta)], [sin(theta), cos(theta)]])

# %%
# %display latex
A = Matrix(ZZ, 2, 2, [2,1, 0,1])
vect = A.eigenvectors_right()
evects=[vect[i][1] for i in range ()]
# Out:
# [
# (1, 0)
# ]

# %%
def show_eigenvectors(A):
    # %display latex
    A.eigenvectors_right()
    return A
# Out:
# [1/4*sqrt(2*sqrt(5) + 10)       -1/4*sqrt(5) + 1/4]
# [       1/4*sqrt(5) - 1/4 1/4*sqrt(2*sqrt(5) + 10)]

# %%
list =[R(pi/20)^n*vector([1,0]) for n in range(1,20)]
list
# Out:
# [(cos(1/20*pi), sin(1/20*pi)),
#  (cos(1/20*pi)^2 - sin(1/20*pi)^2, 2*cos(1/20*pi)*sin(1/20*pi)),
#  (-2*cos(1/20*pi)*sin(1/20*pi)^2 + (cos(1/20*pi)^2 - sin(1/20*pi)^2)*cos(1/20*pi), 2*cos(1/20*pi)^2*sin(1/20*pi) + (cos(1/20*pi)^2 - sin(1/20*pi)^2)*sin(1/20*pi)),
#  (-4*cos(1/20*pi)^2*sin(1/20*pi)^2 + (cos(1/20*pi)^2 - sin(1/20*pi)^2)^2, 4*(cos(1/20*pi)^2 - sin(1/20*pi)^2)*cos(1/20*pi)*sin(1/20*pi)),
#  (-4*(cos(1/20*pi)^2 - sin(1/20*pi)^2)*cos(1/20*pi)*sin(1/20*pi)^2 - (4*cos(1/20*pi)^2*sin(1/20*pi)^2 - (cos(1/20*pi)^2 - sin(1/20*pi)^2)^2)*cos(1/20*pi), 4*(cos(1/20*pi)^2 - sin(1/20*pi)^2)*cos(1/20*pi)^2*sin(1/20*pi) - (4*cos(1/20*pi)^2*sin(1/20*pi)^2 - (cos(1/20*pi)^2 - sin(1/20*pi)^2)^2)*sin(1/20*pi)),
# ...

# %%
sum([arrow2d((0,0), (cos(x),sin(x)), hue=x/(2*pi)) for x in [0..2*pi,step=0.1]])
# Out:
# Graphics object consisting of 63 graphics primitives
